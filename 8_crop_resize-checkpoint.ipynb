# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('robo3.jpg',1)

# %%
plt.title('robo')
plt.imshow(img)

# %% [markdown]
# # Resize

# %%
resiged=cv2.resize(img,(200,300))#(width,height)

# %%
plt.imshow(resiged)

# %% [markdown]
# # Crop

# %%
croped=img[0:600,0:500] # height(from:to) ,width(from:to)

# %%
plt.imshow(croped)
